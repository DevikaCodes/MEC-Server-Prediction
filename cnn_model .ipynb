# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import r2_score, mean_absolute_error
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error



df = pd.read_csv("mec_training_dataset_v2.csv")

# %%
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)



gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=RANDOM_STATE)
train_idx, test_idx = next(gss.split(df, groups=df["Vehicle_ID"]))
train_df, test_df = df.iloc[train_idx].copy(), df.iloc[test_idx].copy()

# %% [markdown]
# Stage1

# %%
stage1_num = ["Speed_kmh", "Traffic_Density", "Urgency_Level", "Latitude", "Longitude"]
stage1_cat = ["Road_Type", "Weather", "Data_Type", "MEC_Server_ID"]

stage1_pre = ColumnTransformer([
    ("num", StandardScaler(), stage1_num),
    ("cat", OneHotEncoder(handle_unknown="ignore"), stage1_cat),
])

X1_train = stage1_pre.fit_transform(train_df[stage1_num + stage1_cat])
X1_test = stage1_pre.transform(test_df[stage1_num + stage1_cat])
y1_train = train_df["Server_Load_Percent"].values
y1_test = test_df["Server_Load_Percent"].values

# CNN needs a 3D input: (samples, features, channels) -- reshape the flat
# feature vector into a "1D signal" the convolution can slide across
n_features_1 = X1_train.shape[1]
X1_train_cnn = X1_train.reshape(-1, n_features_1, 1)
X1_test_cnn = X1_test.reshape(-1, n_features_1, 1)

cnn_stage1 = keras.Sequential([
    layers.Input(shape=(n_features_1, 1)),
    layers.Conv1D(64, kernel_size=3, activation="relu", padding="same"),
    layers.Conv1D(32, kernel_size=3, activation="relu", padding="same"),
    layers.GlobalAveragePooling1D(),
    layers.Dense(32, activation="relu"),
    layers.Dropout(0.2),
    layers.Dense(1),
])
cnn_stage1.compile(optimizer="adam", loss="mse", metrics=["mae"])
history_cnn1 = cnn_stage1.fit(X1_train_cnn, y1_train, validation_split=0.15, epochs=100,
                               batch_size=64, verbose=1)

pred_load_train = cnn_stage1.predict(X1_train_cnn, verbose=0).flatten()
pred_load_test = cnn_stage1.predict(X1_test_cnn, verbose=0).flatten()

print("--- CNN Stage 1: Server_Load_Percent ---")
print(f"Test R2:  {r2_score(y1_test, pred_load_test):.4f}")
print(f"Test MAE: {mean_absolute_error(y1_test, pred_load_test):.2f} points")
# Out:
# Epoch 1/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 5492.3740 - mae: 67.5701 - val_loss: 742.5598 - val_mae: 22.2034
# Epoch 2/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 870.0659 - mae: 22.9451 - val_loss: 730.8711 - val_mae: 22.5271
# Epoch 3/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 849.5353 - mae: 23.0010 - val_loss: 712.8246 - val_mae: 22.0779
# Epoch 4/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 824.6382 - mae: 22.6440 - val_loss: 696.9830 - val_mae: 21.6113
# Epoch 5/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 806.9822 - mae: 22.2285 - val_loss: 684.7309 - val_mae: 20.9329
# Epoch 6/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 805.2960 - mae: 22.2653 - val_loss: 675.7048 - val_mae: 21.1609
# Epoch 7/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 780.3213 - mae: 21.7805 - val_loss: 674.4210 - val_mae: 21.8341
# Epoch 8/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 789.8503 - mae: 21.9817 - val_loss: 675.5493 - val_mae: 22.1817
# Epoch 9/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 780.3233 - mae: 21.8253 - val_loss: 658.4401 - val_mae: 20.7942
# Epoch 10/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 775.1590 - mae: 21.7821 - val_loss: 658.9402 - val_mae: 21.3567
# Epoch 11/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 773.6431 - mae: 21.8154 - val_loss: 658.0402 - val_mae: 21.4382
# Epoch 12/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 776.8708 - mae: 21.7916 - val_loss: 657.9822 - val_mae: 21.5440
# Epoch 13/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 757.2153 - mae: 21.3407 - val_loss: 650.3389 - val_mae: 20.8180
# Epoch 14/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 775.4154 - mae: 21.7303 - val_loss: 649.1283 - val_mae: 20.8272
# Epoch 15/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 764.2848 - mae: 21.5741 - val_loss: 647.0337 - val_mae: 20.2125
# Epoch 16/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 765.4919 - mae: 21.6428 - val_loss: 647.7136 - val_mae: 20.9609
# Epoch 17/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 757.9489 - mae: 21.4547 - val_loss: 656.8873 - val_mae: 21.7720
# Epoch 18/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 758.5207 - mae: 21.4436 - val_loss: 647.1213 - val_mae: 21.1268
# Epoch 19/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 750.6243 - mae: 21.3675 - val_loss: 645.4378 - val_mae: 21.0700
# Epoch 20/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 767.4469 - mae: 21.6170 - val_loss: 656.9632 - val_mae: 21.9142
# Epoch 21/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 758.3365 - mae: 21.4902 - val_loss: 652.1525 - val_mae: 21.6994
# Epoch 22/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 764.6697 - mae: 21.5602 - val_loss: 638.1663 - val_mae: 20.2525
# Epoch 23/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 758.9923 - mae: 21.5465 - val_loss: 640.2653 - val_mae: 20.9531
# Epoch 24/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 779.8385 - mae: 21.9383 - val_loss: 640.1906 - val_mae: 19.3042
# Epoch 25/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 749.5994 - mae: 21.2617 - val_loss: 637.6151 - val_mae: 20.9247
# Epoch 26/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 767.9783 - mae: 21.6319 - val_loss: 646.9133 - val_mae: 21.6554
# Epoch 27/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 758.7673 - mae: 21.5207 - val_loss: 636.2908 - val_mae: 21.0616
# Epoch 28/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 743.3047 - mae: 21.1703 - val_loss: 634.5770 - val_mae: 21.0560
# Epoch 29/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 744.3768 - mae: 21.2051 - val_loss: 628.2219 - val_mae: 20.6485
# Epoch 30/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 744.7487 - mae: 21.1822 - val_loss: 622.4135 - val_mae: 20.0677
# Epoch 31/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 743.1273 - mae: 21.2515 - val_loss: 618.7902 - val_mae: 19.3091
# Epoch 32/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 733.3381 - mae: 20.9771 - val_loss: 609.0814 - val_mae: 20.0738
# Epoch 33/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 719.3477 - mae: 20.8270 - val_loss: 597.7858 - val_mae: 20.0488
# Epoch 34/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 699.9413 - mae: 20.5673 - val_loss: 581.9981 - val_mae: 19.7939
# Epoch 35/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 685.5784 - mae: 20.5331 - val_loss: 565.1502 - val_mae: 19.8248
# Epoch 36/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 671.6134 - mae: 20.2051 - val_loss: 536.3967 - val_mae: 18.9066
# Epoch 37/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 638.7784 - mae: 19.6545 - val_loss: 511.2602 - val_mae: 18.4052
# Epoch 38/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 620.7772 - mae: 19.5494 - val_loss: 480.0016 - val_mae: 16.8636
# Epoch 39/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 576.0837 - mae: 18.8366 - val_loss: 447.4893 - val_mae: 17.0269
# Epoch 40/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 544.0340 - mae: 18.2899 - val_loss: 413.7114 - val_mae: 16.6150
# Epoch 41/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 508.8319 - mae: 17.7360 - val_loss: 385.3527 - val_mae: 16.4529
# Epoch 42/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 481.2551 - mae: 17.4397 - val_loss: 352.1830 - val_mae: 15.7789
# Epoch 43/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 443.9012 - mae: 16.8055 - val_loss: 319.2424 - val_mae: 15.0462
# Epoch 44/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 420.6411 - mae: 16.4614 - val_loss: 315.7844 - val_mae: 15.3472
# Epoch 45/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 382.0048 - mae: 15.7082 - val_loss: 242.4161 - val_mae: 12.5807
# Epoch 46/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 341.2836 - mae: 14.9633 - val_loss: 207.1182 - val_mae: 10.9688
# Epoch 47/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 326.4497 - mae: 14.6274 - val_loss: 185.5900 - val_mae: 10.8670
# Epoch 48/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 298.1566 - mae: 14.0271 - val_loss: 164.1483 - val_mae: 9.9317
# Epoch 49/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 280.2054 - mae: 13.5791 - val_loss: 145.1859 - val_mae: 9.4331
# Epoch 50/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 262.3911 - mae: 13.0277 - val_loss: 142.5195 - val_mae: 9.4005
# Epoch 51/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 248.8609 - mae: 12.7306 - val_loss: 125.0594 - val_mae: 8.7205
# Epoch 52/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 245.4891 - mae: 12.5016 - val_loss: 117.5101 - val_mae: 8.4596
# Epoch 53/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 231.1411 - mae: 12.1910 - val_loss: 123.5250 - val_mae: 8.6873
# Epoch 54/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 231.9851 - mae: 12.1738 - val_loss: 100.6271 - val_mae: 7.7974
# Epoch 55/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 223.5027 - mae: 11.8734 - val_loss: 92.6137 - val_mae: 7.5700
# Epoch 56/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 219.7267 - mae: 11.8334 - val_loss: 88.1674 - val_mae: 7.3114
# Epoch 57/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 208.8627 - mae: 11.4721 - val_loss: 90.7768 - val_mae: 7.5872
# Epoch 58/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 205.2326 - mae: 11.3718 - val_loss: 84.6339 - val_mae: 7.1058
# Epoch 59/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 203.8860 - mae: 11.3738 - val_loss: 77.0231 - val_mae: 6.8593
# Epoch 60/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 205.5990 - mae: 11.3268 - val_loss: 77.9012 - val_mae: 7.0421
# Epoch 61/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 203.2581 - mae: 11.2838 - val_loss: 79.7814 - val_mae: 6.9569
# Epoch 62/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 201.5633 - mae: 11.2611 - val_loss: 71.5474 - val_mae: 6.6220
# Epoch 63/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 196.0233 - mae: 11.1074 - val_loss: 77.3956 - val_mae: 6.9359
# Epoch 64/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 191.2850 - mae: 10.9191 - val_loss: 73.0199 - val_mae: 6.7537
# Epoch 65/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 194.4737 - mae: 10.9921 - val_loss: 70.4468 - val_mae: 6.6122
# Epoch 66/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 199.4523 - mae: 11.0881 - val_loss: 64.3210 - val_mae: 6.2996
# Epoch 67/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 188.0777 - mae: 10.7903 - val_loss: 64.4792 - val_mae: 6.2841
# Epoch 68/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 186.0204 - mae: 10.7361 - val_loss: 64.0997 - val_mae: 6.2573
# Epoch 69/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 185.2567 - mae: 10.6709 - val_loss: 75.3979 - val_mae: 6.9390
# Epoch 70/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 183.0487 - mae: 10.6575 - val_loss: 80.0438 - val_mae: 7.2162
# Epoch 71/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 187.6837 - mae: 10.7924 - val_loss: 58.4272 - val_mae: 5.9748
# Epoch 72/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 186.9652 - mae: 10.7065 - val_loss: 56.6141 - val_mae: 5.7895
# Epoch 73/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 178.0503 - mae: 10.4515 - val_loss: 55.5987 - val_mae: 5.6934
# Epoch 74/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 183.3199 - mae: 10.6558 - val_loss: 66.7625 - val_mae: 6.5138
# Epoch 75/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 178.5405 - mae: 10.4441 - val_loss: 59.2273 - val_mae: 6.0369
# Epoch 76/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 179.7714 - mae: 10.5079 - val_loss: 54.4163 - val_mae: 5.6361
# Epoch 77/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 176.7420 - mae: 10.3867 - val_loss: 68.8877 - val_mae: 6.6825
# Epoch 78/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 179.5419 - mae: 10.5604 - val_loss: 60.9779 - val_mae: 6.1499
# Epoch 79/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 178.3890 - mae: 10.4476 - val_loss: 58.5003 - val_mae: 6.0032
# Epoch 80/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 175.8407 - mae: 10.4487 - val_loss: 60.1817 - val_mae: 5.9589
# Epoch 81/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 181.0692 - mae: 10.5174 - val_loss: 78.9426 - val_mae: 7.3165
# Epoch 82/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 178.0623 - mae: 10.4745 - val_loss: 52.9876 - val_mae: 5.5391
# Epoch 83/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 176.5099 - mae: 10.4296 - val_loss: 53.0118 - val_mae: 5.4660
# Epoch 84/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 180.0643 - mae: 10.4772 - val_loss: 53.8016 - val_mae: 5.6405
# Epoch 85/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 181.6636 - mae: 10.5602 - val_loss: 51.2214 - val_mae: 5.4650
# Epoch 86/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 169.2116 - mae: 10.1770 - val_loss: 56.2560 - val_mae: 5.8848
# Epoch 87/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 175.0923 - mae: 10.3284 - val_loss: 58.5421 - val_mae: 5.8720
# Epoch 88/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 175.4184 - mae: 10.3233 - val_loss: 50.2063 - val_mae: 5.3252
# Epoch 89/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 174.6712 - mae: 10.3020 - val_loss: 50.3898 - val_mae: 5.3176
# Epoch 90/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 175.9131 - mae: 10.3709 - val_loss: 49.2873 - val_mae: 5.2562
# Epoch 91/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 166.9588 - mae: 10.0808 - val_loss: 49.7119 - val_mae: 5.3023
# Epoch 92/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 171.0170 - mae: 10.1594 - val_loss: 59.7461 - val_mae: 6.1664
# Epoch 93/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 170.1556 - mae: 10.1325 - val_loss: 50.3906 - val_mae: 5.3847
# Epoch 94/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 169.2250 - mae: 10.2324 - val_loss: 51.0037 - val_mae: 5.3937
# Epoch 95/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 173.9045 - mae: 10.2433 - val_loss: 50.9793 - val_mae: 5.4807
# Epoch 96/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 173.1428 - mae: 10.2164 - val_loss: 64.4454 - val_mae: 6.5194
# Epoch 97/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 170.6098 - mae: 10.1823 - val_loss: 49.8634 - val_mae: 5.2801
# Epoch 98/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 175.1662 - mae: 10.3253 - val_loss: 55.6909 - val_mae: 5.8659
# Epoch 99/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 166.7237 - mae: 10.0712 - val_loss: 47.3732 - val_mae: 5.1447
# Epoch 100/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 172.0274 - mae: 10.2503 - val_loss: 48.0524 - val_mae: 5.1931
# --- CNN Stage 1: Server_Load_Percent ---
# Test R2:  0.8572
# Test MAE: 8.35 points

# %% [markdown]
# evaluate stage 1

# %%
print("Stage 1 (Server Load)")
print(f"R² Score : {r2_score(y1_test, pred_load_test):.4f}")
print(f"MAE      : {mean_absolute_error(y1_test, pred_load_test):.2f}")
print(f"RMSE     : {np.sqrt(mean_squared_error(y1_test, pred_load_test)):.2f}")
# Out:
# Stage 1 (Server Load)
# R² Score : 0.8572
# MAE      : 8.35
# RMSE     : 10.80

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
plt.plot(history_cnn1.history['loss'], label='Training Loss')
plt.plot(history_cnn1.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('CNN Stage 1: Training vs Validation Loss')
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig('cnn_stage1_loss_curve.png', dpi=300)
plt.show()

# %% [markdown]
# Stage 2:Predict Network Latency

# %%
# ---------------- STAGE 2: 1D-CNN -> Latency_ms ----------------
stage2_num = [
    "Pred_Load",
    "Speed_kmh",
    "Traffic_Density",
    "Latitude",
    "Longitude",
    "Urgency_Level"
]

stage2_cat = [
    "Road_Type",
    "Weather",
    "Data_Type",
    "MEC_Server_ID"
]

stage2_pre = ColumnTransformer([
    ("num", StandardScaler(), stage2_num),
    ("cat", OneHotEncoder(handle_unknown="ignore"), stage2_cat),
])


train_df["Pred_Load"] = pred_load_train
test_df["Pred_Load"] = pred_load_test



X2_train = stage2_pre.fit_transform(train_df[stage2_num + stage2_cat])
X2_test = stage2_pre.transform(test_df[stage2_num + stage2_cat])
y2_train = train_df["Latency_ms"].values
y2_test = test_df["Latency_ms"].values

n_features_2 = X2_train.shape[1]
X2_train_cnn = X2_train.reshape(-1, n_features_2, 1)
X2_test_cnn = X2_test.reshape(-1, n_features_2, 1)

cnn_stage2 = keras.Sequential([
    layers.Input(shape=(n_features_2, 1)),
    layers.Conv1D(64, kernel_size=3, activation="relu", padding="same"),
    layers.Conv1D(32, kernel_size=3, activation="relu", padding="same"),
    layers.GlobalAveragePooling1D(),
    layers.Dense(32, activation="relu"),
    layers.Dropout(0.2),
    layers.Dense(1),
])
cnn_stage2.compile(optimizer="adam", loss="mse", metrics=["mae"])
history_cnn2 = cnn_stage2.fit(X2_train_cnn, y2_train, validation_split=0.15, epochs=100,
                               batch_size=64, verbose=1)

pred_latency_test = cnn_stage2.predict(X2_test_cnn, verbose=0).flatten()
# Out:
# Epoch 1/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 435.5415 - mae: 18.1726 - val_loss: 39.3114 - val_mae: 5.0303
# Epoch 2/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 57.5285 - mae: 6.0141 - val_loss: 38.5194 - val_mae: 4.9786
# Epoch 3/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 56.2360 - mae: 5.9158 - val_loss: 38.5349 - val_mae: 4.9740
# Epoch 4/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 54.6408 - mae: 5.8523 - val_loss: 37.7650 - val_mae: 4.9203
# Epoch 5/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 53.7401 - mae: 5.8282 - val_loss: 37.6098 - val_mae: 4.9113
# Epoch 6/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 52.3771 - mae: 5.7712 - val_loss: 37.1005 - val_mae: 4.8782
# Epoch 7/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 52.9214 - mae: 5.7721 - val_loss: 37.2072 - val_mae: 4.8833
# Epoch 8/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 51.9733 - mae: 5.7430 - val_loss: 37.3470 - val_mae: 4.8930
# Epoch 9/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 52.5227 - mae: 5.7352 - val_loss: 37.7128 - val_mae: 4.9211
# Epoch 10/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 52.5009 - mae: 5.7598 - val_loss: 36.5017 - val_mae: 4.8382
# Epoch 11/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 51.4715 - mae: 5.7098 - val_loss: 36.3804 - val_mae: 4.8251
# Epoch 12/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 50.8031 - mae: 5.6715 - val_loss: 35.7080 - val_mae: 4.7785
# Epoch 13/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 50.9693 - mae: 5.6934 - val_loss: 35.4762 - val_mae: 4.7629
# Epoch 14/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 49.7799 - mae: 5.5956 - val_loss: 35.6204 - val_mae: 4.7709
# Epoch 15/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 49.4553 - mae: 5.5765 - val_loss: 35.5234 - val_mae: 4.7652
# Epoch 16/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 50.1259 - mae: 5.6438 - val_loss: 34.1803 - val_mae: 4.6617
# Epoch 17/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 48.2776 - mae: 5.5230 - val_loss: 33.7964 - val_mae: 4.6395
# Epoch 18/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 49.1816 - mae: 5.5718 - val_loss: 35.5359 - val_mae: 4.7439
# Epoch 19/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 47.1694 - mae: 5.4774 - val_loss: 31.8302 - val_mae: 4.5039
# Epoch 20/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 47.5273 - mae: 5.5100 - val_loss: 31.0009 - val_mae: 4.4320
# Epoch 21/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 45.8945 - mae: 5.3742 - val_loss: 29.1353 - val_mae: 4.3276
# Epoch 22/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 43.9902 - mae: 5.2687 - val_loss: 27.5215 - val_mae: 4.1978
# Epoch 23/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 42.7141 - mae: 5.2385 - val_loss: 26.6142 - val_mae: 4.0938
# Epoch 24/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 40.9917 - mae: 5.0777 - val_loss: 24.8171 - val_mae: 3.9704
# Epoch 25/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 39.3106 - mae: 5.0040 - val_loss: 22.6010 - val_mae: 3.8167
# Epoch 26/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 37.2119 - mae: 4.8402 - val_loss: 20.7906 - val_mae: 3.6659
# Epoch 27/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 35.1296 - mae: 4.7038 - val_loss: 19.0780 - val_mae: 3.5334
# Epoch 28/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 33.9689 - mae: 4.6474 - val_loss: 17.5403 - val_mae: 3.3982
# Epoch 29/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 32.7360 - mae: 4.5530 - val_loss: 17.0254 - val_mae: 3.3566
# Epoch 30/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 32.0366 - mae: 4.4931 - val_loss: 17.2246 - val_mae: 3.3669
# Epoch 31/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31.5174 - mae: 4.4674 - val_loss: 16.7436 - val_mae: 3.3088
# Epoch 32/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31.2315 - mae: 4.4307 - val_loss: 15.1159 - val_mae: 3.1904
# Epoch 33/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 30.3570 - mae: 4.3778 - val_loss: 15.5672 - val_mae: 3.2145
# Epoch 34/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 30.0957 - mae: 4.3695 - val_loss: 16.3769 - val_mae: 3.2717
# Epoch 35/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 29.9947 - mae: 4.3496 - val_loss: 14.3805 - val_mae: 3.0978
# Epoch 36/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 29.9960 - mae: 4.3615 - val_loss: 15.5673 - val_mae: 3.1955
# Epoch 37/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 30.1629 - mae: 4.3587 - val_loss: 14.0336 - val_mae: 3.0583
# Epoch 38/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 30.7168 - mae: 4.4143 - val_loss: 14.1649 - val_mae: 3.0664
# Epoch 39/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 29.3587 - mae: 4.3102 - val_loss: 14.3831 - val_mae: 3.0817
# Epoch 40/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 28.5066 - mae: 4.2283 - val_loss: 14.2932 - val_mae: 3.0639
# Epoch 41/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 28.2629 - mae: 4.2250 - val_loss: 13.4340 - val_mae: 2.9999
# Epoch 42/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 28.9863 - mae: 4.2777 - val_loss: 15.6454 - val_mae: 3.1815
# Epoch 43/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 28.6354 - mae: 4.2627 - val_loss: 13.3599 - val_mae: 2.9846
# Epoch 44/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 28.8355 - mae: 4.2642 - val_loss: 14.4403 - val_mae: 3.0423
# Epoch 45/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 28.9807 - mae: 4.2514 - val_loss: 13.2252 - val_mae: 2.9460
# Epoch 46/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 29.0047 - mae: 4.2653 - val_loss: 14.2153 - val_mae: 3.0346
# Epoch 47/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 27.6363 - mae: 4.1894 - val_loss: 13.1032 - val_mae: 2.9223
# Epoch 48/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 27.5317 - mae: 4.1465 - val_loss: 12.9457 - val_mae: 2.9131
# Epoch 49/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 27.3239 - mae: 4.1461 - val_loss: 13.6922 - val_mae: 2.9709
# Epoch 50/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 27.1378 - mae: 4.1337 - val_loss: 12.5839 - val_mae: 2.8912
# Epoch 51/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 26.8196 - mae: 4.0787 - val_loss: 13.1142 - val_mae: 2.9289
# Epoch 52/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 28.0011 - mae: 4.2042 - val_loss: 12.1834 - val_mae: 2.8747
# Epoch 53/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 26.6210 - mae: 4.0887 - val_loss: 12.3747 - val_mae: 2.8995
# Epoch 54/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 27.0383 - mae: 4.1155 - val_loss: 12.6370 - val_mae: 2.9316
# Epoch 55/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 26.5942 - mae: 4.0972 - val_loss: 12.9491 - val_mae: 2.8890
# Epoch 56/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 26.4902 - mae: 4.0545 - val_loss: 11.8799 - val_mae: 2.8160
# Epoch 57/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 26.3632 - mae: 4.0743 - val_loss: 11.7456 - val_mae: 2.8182
# Epoch 58/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 26.7638 - mae: 4.0922 - val_loss: 12.1984 - val_mae: 2.8372
# Epoch 59/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 25.6741 - mae: 3.9981 - val_loss: 12.4249 - val_mae: 2.8293
# Epoch 60/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 25.6789 - mae: 4.0088 - val_loss: 11.6030 - val_mae: 2.7802
# Epoch 61/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 26.1919 - mae: 4.0586 - val_loss: 11.4381 - val_mae: 2.7334
# Epoch 62/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 24.7600 - mae: 3.9316 - val_loss: 11.4259 - val_mae: 2.7372
# Epoch 63/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 25.1470 - mae: 3.9687 - val_loss: 13.9949 - val_mae: 2.9585
# Epoch 64/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 25.0644 - mae: 3.9639 - val_loss: 10.9244 - val_mae: 2.6807
# Epoch 65/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 25.0325 - mae: 3.9192 - val_loss: 11.2541 - val_mae: 2.7188
# Epoch 66/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 24.4669 - mae: 3.9093 - val_loss: 11.7465 - val_mae: 2.7109
# Epoch 67/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 24.2397 - mae: 3.9033 - val_loss: 10.8761 - val_mae: 2.6752
# Epoch 68/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 24.4097 - mae: 3.9288 - val_loss: 10.5044 - val_mae: 2.6369
# Epoch 69/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 24.4026 - mae: 3.9193 - val_loss: 10.8450 - val_mae: 2.7040
# Epoch 70/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 24.1695 - mae: 3.8988 - val_loss: 10.5040 - val_mae: 2.6430
# Epoch 71/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 24.3465 - mae: 3.8874 - val_loss: 10.8726 - val_mae: 2.6377
# Epoch 72/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 24.2465 - mae: 3.8960 - val_loss: 10.3734 - val_mae: 2.5993
# Epoch 73/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 24.1326 - mae: 3.8775 - val_loss: 10.2416 - val_mae: 2.5733
# Epoch 74/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 24.0288 - mae: 3.8698 - val_loss: 9.9993 - val_mae: 2.5600
# Epoch 75/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 23.9773 - mae: 3.8635 - val_loss: 10.3074 - val_mae: 2.5746
# Epoch 76/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 23.0021 - mae: 3.7890 - val_loss: 10.2631 - val_mae: 2.5799
# Epoch 77/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 23.3707 - mae: 3.8009 - val_loss: 9.9140 - val_mae: 2.5138
# Epoch 78/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 23.3701 - mae: 3.7831 - val_loss: 9.9923 - val_mae: 2.5177
# Epoch 79/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 23.2858 - mae: 3.8014 - val_loss: 12.8423 - val_mae: 2.7985
# Epoch 80/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 22.9120 - mae: 3.7457 - val_loss: 9.5418 - val_mae: 2.4879
# Epoch 81/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 23.3074 - mae: 3.7738 - val_loss: 9.5266 - val_mae: 2.4696
# Epoch 82/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 22.3030 - mae: 3.7114 - val_loss: 9.8157 - val_mae: 2.4808
# Epoch 83/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 22.4054 - mae: 3.7136 - val_loss: 9.5510 - val_mae: 2.4681
# Epoch 84/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 21.7863 - mae: 3.6904 - val_loss: 11.1639 - val_mae: 2.6463
# Epoch 85/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 21.8912 - mae: 3.6691 - val_loss: 9.1862 - val_mae: 2.4188
# Epoch 86/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 21.8402 - mae: 3.6606 - val_loss: 10.0739 - val_mae: 2.4950
# Epoch 87/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 21.6487 - mae: 3.6678 - val_loss: 11.0734 - val_mae: 2.5837
# Epoch 88/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 21.4249 - mae: 3.6391 - val_loss: 8.9351 - val_mae: 2.3986
# Epoch 89/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 21.2103 - mae: 3.6101 - val_loss: 8.9059 - val_mae: 2.3599
# Epoch 90/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 22.1769 - mae: 3.6972 - val_loss: 8.7845 - val_mae: 2.3699
# Epoch 91/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 21.2837 - mae: 3.6358 - val_loss: 8.8602 - val_mae: 2.3559
# Epoch 92/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 20.8125 - mae: 3.5928 - val_loss: 8.6863 - val_mae: 2.3506
# Epoch 93/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 21.0306 - mae: 3.5802 - val_loss: 9.0462 - val_mae: 2.3564
# Epoch 94/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 21.0610 - mae: 3.6034 - val_loss: 8.9054 - val_mae: 2.3385
# Epoch 95/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 20.7658 - mae: 3.5989 - val_loss: 8.3995 - val_mae: 2.2910
# Epoch 96/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 20.4184 - mae: 3.5493 - val_loss: 9.5841 - val_mae: 2.3955
# Epoch 97/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 21.4798 - mae: 3.6538 - val_loss: 8.3584 - val_mae: 2.2924
# Epoch 98/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 20.3502 - mae: 3.5497 - val_loss: 9.0127 - val_mae: 2.4029
# Epoch 99/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 20.0084 - mae: 3.5013 - val_loss: 8.3859 - val_mae: 2.2586
# Epoch 100/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 20.0650 - mae: 3.5150 - val_loss: 8.3313 - val_mae: 2.2632

# %% [markdown]
# evaluting stage 2 performance

# %%
print("\nStage 2 (Latency)")
print(f"R² Score : {r2_score(y2_test, pred_latency_test):.4f}")
print(f"MAE      : {mean_absolute_error(y2_test, pred_latency_test):.2f} ms")
print(f"RMSE     : {np.sqrt(mean_squared_error(y2_test, pred_latency_test)):.2f} ms")
# Out:
# Stage 2 (Latency)
# R² Score : 0.1647
# MAE      : 5.22 ms
# RMSE     : 6.64 ms

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
plt.plot(history_cnn1.history['loss'], label='Training Loss')
plt.plot(history_cnn1.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('CNN Stage 1: Training vs Validation Loss')
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig('cnn_stage1_loss_curve.png', dpi=300)
plt.show()

# %%
def prediction_accuracy(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    mask = y_true != 0
    mape = np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100
    return 100 - mape

cnn_load_accuracy = prediction_accuracy(y1_test, pred_load_test)
cnn_latency_accuracy = prediction_accuracy(y2_test, pred_latency_test)

print(f"CNN Stage 1 (Load) Accuracy: {cnn_load_accuracy:.2f}%")
print(f"CNN Stage 2 (Latency) Accuracy: {cnn_latency_accuracy:.2f}%")
# Out:
# CNN Stage 1 (Load) Accuracy: 86.39%
# CNN Stage 2 (Latency) Accuracy: 79.48%

# %% [markdown]
# MEC Server Selection

# %%
test_vehicles = test_df["Vehicle_ID"].unique()
all_servers = df["MEC_Server_ID"].unique()

rows = []
for vid in test_vehicles:
    vehicle_row = test_df[test_df["Vehicle_ID"] == vid].iloc[0]
    for server_id in all_servers:
        row = vehicle_row.copy()
        row["MEC_Server_ID"] = server_id
        rows.append(row)

candidates = pd.DataFrame(rows).reset_index(drop=True)

X1_cand = stage1_pre.transform(candidates[stage1_num + stage1_cat])
X1_cand_cnn = X1_cand.reshape(-1, n_features_1, 1)
candidates["Pred_Load"] = cnn_stage1.predict(X1_cand_cnn, verbose=0).flatten()

X2_cand = stage2_pre.transform(candidates[stage2_num + stage2_cat])
X2_cand_cnn = X2_cand.reshape(-1, n_features_2, 1)
candidates["Pred_Latency"] = cnn_stage2.predict(X2_cand_cnn, verbose=0).flatten()

cnn_best_choice = candidates.loc[candidates.groupby("Vehicle_ID")["Pred_Latency"].idxmin()]

print("CNN Shape of best_choice:", cnn_best_choice.shape)
print("\nCNN - How often each server gets picked as best:")
print(cnn_best_choice["MEC_Server_ID"].value_counts())
# Out:
# CNN Shape of best_choice: (40, 16)
#
# CNN - How often each server gets picked as best:
# MEC_Server_ID
# 5.0    24
# 3.0     5
# 4.0     4
# 6.0     3
# 1.0     3
# 2.0     1
# Name: count, dtype: int64
